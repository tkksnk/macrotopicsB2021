# %%
using SparseArrays
using LinearAlgebra

# parameters
σ = 2.0 #1.2 #2.0   # CRRA utility with parameter s
r = -0.05 #0.035 #0.03  # interest rate
ρ = 0.05  # discount rate
z1 = .1
z2 = .2
z = [z1 z2]
λ1 = 1.5 #0.02 # arrival rate when z=z1
λ2 = 1.0 #0.03 # arrival rate when z=z2
λ = [λ1 λ2]

# number of grid points
na = 500
# set up the grid
amin = -0.15
amax = 10.0
a = collect(range(amin,stop=amax,length=na))
# distance between each grid
da = (amax-amin)/(na-1)

maxit = 20000 # maximum number of iterations
crit  = 1e-6; # convergence criteria

# %%
function vfict_implicit(v0,a,z,σ,ρ,maxit,crit,Delta)

    na = size(a,1)
    amin = minimum(a)
    amax = maximum(a)
    da = (amax-amin)/(na-1)
    
    # for iteration
    dVf = zeros(na,2) # forward difference
    dVb = zeros(na,2) # backward difference
    c   = zeros(na,2) # optimal consumption (from dV)
    AT  = zeros(2*na,2*na)

    # (na,nz) matrix
    aa = [a a]
    zz = ones(na,1)*z

    Aswitch = [-sparse(I,na,na)*λ[1] sparse(I,na,na)*λ[1]; sparse(I,na,na)*λ[2] -sparse(I,na,na)*λ[2]]

    v = v0 # new v
    V = v  # old v

    dist  = zeros(maxit) # distance between old and new value functions at each iteration

    # MAIN LOOP
    for n in 1:maxit

        # forward difference
        dVf[1:na-1,:] = (V[2:na,:]-V[1:na-1,:])/da
    #     dVf[na,:] = (z .+ r.*amax).^(-σ) # state constraint, for stability with implicit method?
        dVf[na,:] = zeros(1,2) # will never be used (as s<0)
        # backward difference
        dVb[2:na,:] = (V[2:na,:]-V[1:na-1,:])/da
        dVb[1,:] = (z .+ r.*amin).^(-σ) # state constraint, for stability with implicit method?
    #     dVb[1] = zeros(1,2) # will never be used (as s>0)

        # consumption and savings with forward difference
        cf = dVf.^(-1/σ)
        sf = zz + r.*aa - cf
        # consumption and savings with backward difference
        cb = dVb.^(-1/σ)
        sb = zz + r.*aa - cb
        # consumption and derivative of value function at steady state (used for c only)
        c0  = zz + r.*aa
        dV0 = c0.^(-σ)

        # dV_upwind makes a choice of forward or backward differences based on
        # the sign of the drift    
        If = sf .> 0       # below steady state
        Ib = sb .< 0       # above steady state
        I0 = (1.0.-If.-Ib) # at steady state

        # make sure the right approximations are used at the boundaries
    #     # at ik = 1, s>0 -> f is used
    #     Ib[1] = 0 
    #     If[1] = 1
    #     # at ik = nk, s<0 -> b is used
        Ib[na,:] = ones(1,2)
        If[na,:] = zeros(1,2)

        dV_Upwind = dVf.*If + dVb.*Ib + dV0.*I0 # important to include third term    
        c = dV_Upwind.^(-1.0/σ)
        u = c.^(1.0-σ)/(1.0-σ)

        # CONSTRUCT MATRIX
        X = -sb.*Ib/da
        Y = -sf.*If/da + sb.*Ib/da
        Z = sf.*If/da

        A1 = spdiagm(na,na,[0 => Y[1:na,1]]...) + spdiagm(na,na,[-1 => X[2:na,1]]...) + spdiagm(na,na,[1 => Z[1:na-1,1]]...)
        A2 = spdiagm(na,na,[0 => Y[1:na,2]]...) + spdiagm(na,na,[-1 => X[2:na,2]]...) + spdiagm(na,na,[1 => Z[1:na-1,2]]...)
        A = [A1 spzeros(na,na); spzeros(na,na) A2] + Aswitch

        # implicit method, with sparse matrix
        B = (Delta*ρ + 1.0)*sparse(1.0I, 2*na, 2*na) - Delta*A
        u_stacked = [u[:,1]; u[:,2]]
        V_stacked = [V[:,1]; V[:,2]]
        b = Delta*u_stacked + V_stacked
        v_stacked = B\b # new v
        v = [v_stacked[1:na] v_stacked[na+1:2*na]]
        Vchange = V - v
        V = v

        dist[n] = maximum(abs.(Vchange))
#         if (mod(n,10)==0)
#             println([n,dist[n]])
#         end
        if dist[n]<crit
#             println("Value Function Converged, Iteration = ")
#             println(n)
            AT = A'
            break
        end
    end
    
    return v, c, AT
    
end
# Out:
# vfict_implicit (generic function with 1 method)

# %%
function fokker_planck(AT)

    # fokker-planck equation
    # AT = A'
    na = Int(size(AT,1)/2)
    
    b = zeros(2*na,1)

    # need to fix one value, otherwise matrix is singular
    i_fix = 1
    b[i_fix] = .1
    row = [zeros(1,i_fix-1) 1 zeros(1,2*na-i_fix)]
    AT[i_fix,:] = row

    # Solve linear system
    gg = AT\b
    g_sum = gg'*ones(2*na,1)*da
    gg = gg./g_sum

    g = [gg[1:na] gg[na+1:2*na]]
    

    return g
    
end
# Out:
# fokker_planck (generic function with 1 method)

# %%
# INITIAL GUESS
# v0 = (A.*k.^α).^(1.0-σ)/(1.0-σ)/ρ
v0 = zeros(na,2)
r = 0.01
v0[:,1] = (z[1] .+ r.*a).^(1.0-σ)/(1.0-σ)/ρ
v0[:,2] = (z[2] .+ r.*a).^(1.0-σ)/(1.0-σ)/ρ

Delta = 1000
@time v,c,AT = vfict_implicit(v0,a,z,σ,ρ,maxit,crit,Delta);
@time g = fokker_planck(AT);
# Out:
#   5.771234 seconds (17.75 M allocations: 903.171 MiB, 4.52% gc time)
#   0.819575 seconds (2.10 M allocations: 106.786 MiB, 5.36% gc time)

# %%
nr = 20
rmin = -0.05
rmax = 0.04
rgrid = collect(range(rmin,stop=rmax,length=nr))
S = zeros(nr)

for ir in 1:nr
    
    r = rgrid[ir]
    @time v0,c,AT = vfict_implicit(v0,a,z,σ,ρ,maxit,crit,Delta);
    @time g = fokker_planck(AT);    
    S[ir] = g[:,1]'*a*da + g[:,2]'*a*da

end
# Out:
#   0.012118 seconds (4.17 k allocations: 27.098 MiB)
#   0.000932 seconds (136 allocations: 1.082 MiB)
#   0.006642 seconds (1.92 k allocations: 16.508 MiB)
#   0.000848 seconds (136 allocations: 1.083 MiB)
#   0.006721 seconds (1.92 k allocations: 16.508 MiB)
#   0.000861 seconds (136 allocations: 1.082 MiB)
#   0.010456 seconds (1.94 k allocations: 16.510 MiB, 32.22% gc time)
#   0.000858 seconds (136 allocations: 1.083 MiB)
#   0.006501 seconds (2.37 k allocations: 18.626 MiB)
#   0.000875 seconds (136 allocations: 1.082 MiB)
#   0.010024 seconds (2.40 k allocations: 18.628 MiB, 21.68% gc time)
#   0.000802 seconds (136 allocations: 1.083 MiB)
#   0.006469 seconds (2.37 k allocations: 18.626 MiB)
#   0.000785 seconds (136 allocations: 1.083 MiB)
#   0.024473 seconds (2.40 k allocations: 18.629 MiB, 74.18% gc time)
#   0.000839 seconds (136 allocations: 1.083 MiB)
#   0.006475 seconds (2.37 k allocations: 18.626 MiB)
#   0.000780 seconds (136 allocations: 1.083 MiB)
#   0.006102 seconds (2.37 k allocations: 18.626 MiB)
#   0.000785 seconds (136 allocations: 1.083 MiB)
#   0.066358 seconds (2.40 k allocations: 18.629 MiB, 87.63% gc time)
#   0.000830 seconds (136 allocations: 1.083 MiB)
#   0.006603 seconds (2.37 k allocations: 18.627 MiB)
#   0.000871 seconds (136 allocations: 1.083 MiB)
#   0.052721 seconds (2.40 k allocations: 18.629 MiB, 86.95% gc time)
#   0.000826 seconds (136 allocations: 1.083 MiB)
#   0.006561 seconds (2.37 k allocations: 18.627 MiB)
#   0.000796 seconds (136 allocations: 1.083 MiB)
#   0.008819 seconds (2.40 k allocations: 18.630 MiB, 9.60% gc time)
#   0.000804 seconds (136 allocations: 1.083 MiB)
#   0.006483 seconds (2.37 k allocations: 18.628 MiB)
#   0.000784 seconds (136 allocations: 1.083 MiB)
#   0.006161 seconds (2.37 k allocations: 18.628 MiB)
#   0.000788 seconds (136 allocations: 1.083 MiB)
#   0.008714 seconds (2.40 k allocations: 18.632 MiB, 8.92% gc time)
#   0.000775 seconds (136 allocations: 1.084 MiB)
#   0.006201 seconds (2.37 k allocations: 18.633 MiB)
#   0.000810 seconds (136 allocations: 1.086 MiB)
#   0.008376 seconds (2.40 k allocations: 18.647 MiB, 19.99% gc time)
#   0.000822 seconds (136 allocations: 1.091 MiB)

# %%
using Plots
plot(S,rgrid)
