# %%
using SparseArrays
using LinearAlgebra

# parameters
σ = 2.0 #1.2 #2.0   # CRRA utility with parameter s
r = -0.05 #0.035 #0.03  # interest rate
ρ = 0.05  # discount rate
z1 = .1
z2 = .2
z = [z1 z2]
λ1 = 1.5 #0.02 # arrival rate when z=z1
λ2 = 1.0 #0.03 # arrival rate when z=z2
λ = [λ1 λ2]

# number of grid points
na = 500
# set up the grid
amin = -0.15
amax = 10.0
a = collect(range(amin,stop=amax,length=na))
# distance between each grid
da = (amax-amin)/(na-1)

maxit = 20000 # maximum number of iterations
crit  = 1e-6; # convergence criteria

# %%
function vfict_implicit(v0,a,z,σ,ρ,maxit,crit,Delta)

    na = size(a,1)
    amin = minimum(a)
    amax = maximum(a)
    da = (amax-amin)/(na-1)
    
    # for iteration
    dVf = zeros(na,2) # forward difference
    dVb = zeros(na,2) # backward difference
    c   = zeros(na,2) # optimal consumption (from dV)
    AT  = zeros(2*na,2*na)

    # (na,nz) matrix
    aa = [a a]
    zz = ones(na,1)*z

    Aswitch = [-sparse(I,na,na)*λ[1] sparse(I,na,na)*λ[1]; sparse(I,na,na)*λ[2] -sparse(I,na,na)*λ[2]]

    v = v0 # new v
    V = v  # old v

    dist  = zeros(maxit) # distance between old and new value functions at each iteration

    # MAIN LOOP
    for n in 1:maxit

        # forward difference
        dVf[1:na-1,:] = (V[2:na,:]-V[1:na-1,:])/da
    #     dVf[na,:] = (z .+ r.*amax).^(-σ) # state constraint, for stability with implicit method?
        dVf[na,:] = zeros(1,2) # will never be used (as s<0)
        # backward difference
        dVb[2:na,:] = (V[2:na,:]-V[1:na-1,:])/da
        dVb[1,:] = (z .+ r.*amin).^(-σ) # state constraint, for stability with implicit method?
    #     dVb[1] = zeros(1,2) # will never be used (as s>0)

        # consumption and savings with forward difference
        cf = dVf.^(-1/σ)
        sf = zz + r.*aa - cf
        # consumption and savings with backward difference
        cb = dVb.^(-1/σ)
        sb = zz + r.*aa - cb
        # consumption and derivative of value function at steady state (used for c only)
        c0  = zz + r.*aa
        dV0 = c0.^(-σ)

        # dV_upwind makes a choice of forward or backward differences based on
        # the sign of the drift    
        If = sf .> 0       # below steady state
        Ib = sb .< 0       # above steady state
        I0 = (1.0.-If.-Ib) # at steady state

        # make sure the right approximations are used at the boundaries
    #     # at ik = 1, s>0 -> f is used
    #     Ib[1] = 0 
    #     If[1] = 1
    #     # at ik = nk, s<0 -> b is used
        Ib[na,:] = ones(1,2)
        If[na,:] = zeros(1,2)

        dV_Upwind = dVf.*If + dVb.*Ib + dV0.*I0 # important to include third term    
        c = dV_Upwind.^(-1.0/σ)
        u = c.^(1.0-σ)/(1.0-σ)

        # CONSTRUCT MATRIX
        X = -sb.*Ib/da
        Y = -sf.*If/da + sb.*Ib/da
        Z = sf.*If/da

        A1 = spdiagm(na,na,[0 => Y[1:na,1]]...) + spdiagm(na,na,[-1 => X[2:na,1]]...) + spdiagm(na,na,[1 => Z[1:na-1,1]]...)
        A2 = spdiagm(na,na,[0 => Y[1:na,2]]...) + spdiagm(na,na,[-1 => X[2:na,2]]...) + spdiagm(na,na,[1 => Z[1:na-1,2]]...)
        A = [A1 spzeros(na,na); spzeros(na,na) A2] + Aswitch

        # implicit method, with sparse matrix
        B = (Delta*ρ + 1.0)*sparse(1.0I, 2*na, 2*na) - Delta*A
        u_stacked = [u[:,1]; u[:,2]]
        V_stacked = [V[:,1]; V[:,2]]
        b = Delta*u_stacked + V_stacked
        v_stacked = B\b # new v
        v = [v_stacked[1:na] v_stacked[na+1:2*na]]
        Vchange = V - v
        V = v

        dist[n] = maximum(abs.(Vchange))
#         if (mod(n,10)==0)
#             println([n,dist[n]])
#         end
        if dist[n]<crit
#             println("Value Function Converged, Iteration = ")
#             println(n)
            AT = A'
            break
        end
    end
    
    return v, c, AT
    
end
# Out:
# vfict_implicit (generic function with 1 method)

# %%
function fokker_planck(AT)

    # fokker-planck equation
    # AT = A'
    na = Int(size(AT,1)/2)
    
    b = zeros(2*na,1)

    # need to fix one value, otherwise matrix is singular
    i_fix = 1
    b[i_fix] = .1
    row = [zeros(1,i_fix-1) 1 zeros(1,2*na-i_fix)]
    AT[i_fix,:] = row

    # Solve linear system
    gg = AT\b
    g_sum = gg'*ones(2*na,1)*da
    gg = gg./g_sum

    g = [gg[1:na] gg[na+1:2*na]]
    

    return g
    
end
# Out:
# fokker_planck (generic function with 1 method)

# %%
# INITIAL GUESS
# v0 = (A.*k.^α).^(1.0-σ)/(1.0-σ)/ρ
v0 = zeros(na,2)
r = 0.01
v0[:,1] = (z[1] .+ r.*a).^(1.0-σ)/(1.0-σ)/ρ
v0[:,2] = (z[2] .+ r.*a).^(1.0-σ)/(1.0-σ)/ρ

Delta = 1000
@time v,c,AT = vfict_implicit(v0,a,z,σ,ρ,maxit,crit,Delta);
@time g = fokker_planck(AT);
# Out:
#   6.821213 seconds (16.57 M allocations: 964.833 MiB, 4.64% gc time, 99.47% compilation time)
#   1.142406 seconds (2.74 M allocations: 158.765 MiB, 4.76% gc time, 99.79% compilation time)

# %%
nr = 20
rmin = -0.05
rmax = 0.04
rgrid = collect(range(rmin,stop=rmax,length=nr))
S = zeros(nr)

for ir in 1:nr
    
    r = rgrid[ir]
    @time v0,c,AT = vfict_implicit(v0,a,z,σ,ρ,maxit,crit,Delta);
    @time g = fokker_planck(AT);    
    S[ir] = g[:,1]'*a*da + g[:,2]'*a*da

end
# Out:
#   0.022344 seconds (4.17 k allocations: 27.098 MiB)
#   0.001447 seconds (107 allocations: 1.081 MiB)
#   0.009938 seconds (1.92 k allocations: 16.508 MiB)
#   0.001247 seconds (107 allocations: 1.081 MiB)
#   0.010423 seconds (1.92 k allocations: 16.508 MiB)
#   0.001043 seconds (107 allocations: 1.081 MiB)
#   0.014832 seconds (1.94 k allocations: 16.510 MiB, 35.66% gc time)
#   0.001105 seconds (107 allocations: 1.081 MiB)
#   0.011192 seconds (2.37 k allocations: 18.626 MiB)
#   0.001190 seconds (107 allocations: 1.081 MiB)
#   0.016668 seconds (2.40 k allocations: 18.628 MiB, 25.57% gc time)
#   0.001071 seconds (107 allocations: 1.081 MiB)
#   0.010744 seconds (2.37 k allocations: 18.626 MiB)
#   0.001136 seconds (107 allocations: 1.081 MiB)
#   0.035517 seconds (2.40 k allocations: 18.629 MiB, 66.68% gc time)
#   0.001291 seconds (107 allocations: 1.081 MiB)
#   0.011576 seconds (2.37 k allocations: 18.626 MiB)
#   0.001332 seconds (107 allocations: 1.082 MiB)
#   0.014379 seconds (2.37 k allocations: 18.626 MiB)
#   0.001503 seconds (107 allocations: 1.082 MiB)
#   0.129537 seconds (2.40 k allocations: 18.629 MiB, 89.43% gc time)
#   0.001294 seconds (107 allocations: 1.082 MiB)
#   0.012299 seconds (2.37 k allocations: 18.627 MiB)
#   0.001242 seconds (107 allocations: 1.082 MiB)
#   0.074915 seconds (2.40 k allocations: 18.629 MiB, 83.45% gc time)
#   0.001064 seconds (107 allocations: 1.082 MiB)
#   0.010776 seconds (2.37 k allocations: 18.627 MiB)
#   0.001069 seconds (107 allocations: 1.082 MiB)
#   0.013545 seconds (2.40 k allocations: 18.630 MiB, 15.73% gc time)
#   0.001594 seconds (107 allocations: 1.082 MiB)
#   0.010721 seconds (2.37 k allocations: 18.628 MiB)
#   0.001037 seconds (107 allocations: 1.082 MiB)
#   0.010698 seconds (2.37 k allocations: 18.628 MiB)
#   0.001072 seconds (107 allocations: 1.082 MiB)
#   0.013215 seconds (2.40 k allocations: 18.632 MiB, 16.50% gc time)
#   0.001042 seconds (107 allocations: 1.083 MiB)
#   0.011985 seconds (2.37 k allocations: 18.633 MiB)
#   0.001158 seconds (107 allocations: 1.085 MiB)
#   0.014330 seconds (2.40 k allocations: 18.647 MiB, 14.05% gc time)
#   0.001211 seconds (107 allocations: 1.090 MiB)

# %%
using Plots
plot(S,rgrid)
